# %%
import numpy as np
import matplotlib.pyplot as plt
from radon import radon
# %config InlineBackend.figure_format='retina'

# %%
params = {"ytick.color" : "w",
          "xtick.color" : "w",
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w",
          "axes.titlecolor" : "w"}
plt.rcParams.update(params)

# %%
rust_radon_transform = np.loadtxt("../outputs/radon_transform.csv", delimiter = ",")
image = np.loadtxt("../inputs/lena.csv", delimiter = ",")
plt.figure(dpi=150, figsize = (6, 3))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap = "viridis")
plt.title("Original image (Lena)")
plt.subplot(1, 2, 2)
plt.imshow(rust_radon_transform, cmap = "viridis")
plt.xlabel("Rays")
plt.ylabel("Slopes")
plt.subplots_adjust(wspace = .35)
plt.title("Radon transform")
plt.savefig("../figures/radon_transform.png", dpi = 150)
